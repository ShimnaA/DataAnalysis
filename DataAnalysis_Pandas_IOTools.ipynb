# %%
import pandas as pd

# %%
df= pd.read_excel('Table_1_Crime_in_the_United_States_by_Volume_and_Rate_per_100000_Inhabitants_1997-2016.xls')

# %%
df.head()
# Out:
#     Year  Violent\ncrime2  Violent \ncrime \nrate   \
# 0   1997          1636096                    611.0
# 1   1998          1533887                    567.6
# 2   1999          1426044                    523.0
# 3   2000          1425486                    506.5
# 4  20015          1439480                    504.5
#
#    Murder and\nnonnegligent \nmanslaughter  \
# 0                                    18208
# 1                                    16974
# 2                                    15522
# 3                                    15586
# 4                                    16037
#
#    Murder and \nnonnegligent \nmanslaughter \nrate   Robbery  Robbery \nrate   \
# 0                                               6.8   498534            186.2
# 1                                               6.3   447186            165.5
# 2                                               5.7   409371            150.1
# ...

# %%
df.to_csv("Table1Crime.csv")

# %%
df['Robbery'].to_csv("Roberry.csv")

# %%
df.set_index("Year")
# Out:
#        Violent\ncrime2  Violent \ncrime \nrate   \
# Year
# 1997           1636096                    611.0
# 1998           1533887                    567.6
# 1999           1426044                    523.0
# 2000           1425486                    506.5
# 20015          1439480                    504.5
# 2002           1423677                    494.4
# 2003           1383676                    475.8
# 2004           1360088                    463.2
# 2005           1390745                    469.0
# 2006           1435123                    479.3
# 2007           1422970                    471.8
# 2008           1394461                    458.6
# 2009           1325896                    431.9
# 2010           1251248                    404.5
# 2011           1206005                    387.1
# 2012           1217057                    387.8
# 2013           1168298                    369.1
# 2014           1153022                    361.6
# ...

# %%
df.set_index("Year", inplace=True)

# %%
df.head()
# Out:
#        Violent\ncrime2  Violent \ncrime \nrate   \
# Year
# 1997           1636096                    611.0
# 1998           1533887                    567.6
# 1999           1426044                    523.0
# 2000           1425486                    506.5
# 20015          1439480                    504.5
#
#        Murder and\nnonnegligent \nmanslaughter  \
# Year
# 1997                                     18208
# 1998                                     16974
# 1999                                     15522
# 2000                                     15586
# 20015                                    16037
#
#        Murder and \nnonnegligent \nmanslaughter \nrate   Robbery  \
# Year
# 1997                                                6.8   498534
# 1998                                                6.3   447186
# 1999                                                5.7   409371
# 2000                                                5.5   408016
# ...

# %%
df['Robbery'].to_csv("newcsv.csv")

# %% [markdown]
# We Get Date as Index

# %%
df = pd.read_csv("newcsv.csv", index_col =0)

# %%
df.head()
# Out:
#        Robbery
# Year
# 1997    498534
# 1998    447186
# 1999    409371
# 2000    408016
# 20015   423557

# %%
df = pd.read_csv("newcsv.csv", index_col =0, names=["Date", 'Robbery_Data'])

# %%
df.head()
# Out:
#      Robbery_Data
# Date
# Year      Robbery
# 1997       498534
# 1998       447186
# 1999       409371
# 2000       408016

# %%
df1 = pd.DataFrame({'A': [1, 2, 3], 'B': [4, 5, 6]}, index=['a', 'b', 'c'])

# %%
df1
# Out:
#    A  B
# a  1  4
# b  2  5
# c  3  6

# %%
store = pd.HDFStore("hdfStore.h5")
print(store)
# Out:
# <class 'pandas.io.pytables.HDFStore'>
# File path: hdfStore.h5

# %%
store.put("d1", df, format="table"  )

# %%
print(store["d1"].shape)
# Out:
# (21, 1)

# %%
store.close()

# %%
hdf = pd.read_hdf("hdfstore.h5", "d1")

# %%
hdf.head()
# Out:
#      Robbery_Data
# Date
# Year      Robbery
# 1997       498534
# 1998       447186
# 1999       409371
# 2000       408016

# %%
hdf.to_json("example.json")

# %%
df2 = pd.read_json("example.json")

# %%
df2.head()
# Out:
#       Robbery_Data
# 1997        498534
# 1998        447186
# 1999        409371
# 2000        408016
# 20015       423557

# %%
df_json = pd.read_json("gross-general-government-debt-esa2010-as-a-percentage-of-the-annualised-gross-domestic-product-by-st-1.json")

# %%
df_json.head()
# Out:
#                                                      dataset
# dimension  {'State': {'label': 'State', 'category': {'ind...
# label      Gross General Government Debt ESA2010 as a Per...
# source                    Central Statistics Office, Ireland
# updated                                 2018-01-19T01:07:40Z
# value      [45.4, 42.9, 39.6, 36.1, 34.4, 32.8, 33.0, 33....

# %%
debt_json1 = urllib.request.urlopen('https://api.publicapis.org/entries').read()

# %%
df_json1 = pd.read_json(debt_json)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-63-509434747b8b> in <module>
# ----> 1 df_json1 = pd.read_json(debt_json)
#
# f:\Users\user\anaconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     212                 else:
#     213                     kwargs[new_arg_name] = new_arg_value
# --> 214             return func(*args, **kwargs)
#     215
#     216         return cast(F, wrapper)
#
# f:\Users\user\anaconda3\lib\site-packages\pandas\io\json\_json.py in read_json(path_or_buf, orient, typ, dtype, convert_axes, convert_dates, keep_default_dates, numpy, precise_float, date_unit, encoding, lines, chunksize, compression)
#     606         return json_reader
#     607
# --> 608     result = json_reader.read()
#     609     if should_close:
#     610         filepath_or_buffer.close()
#
# ...

# %%
import urllib.request
debt_json = urllib.request.urlopen('https://api.coindesk.com/v1/bpi/currentprice.json').read()

# %%
df_json = pd.read_json(debt_json)

# %%
df_json.head()
# Out:
#                                  time  \
# updated     Nov 23, 2020 09:09:00 UTC
# updatedISO  2020-11-23T09:09:00+00:00
# updateduk   Nov 23, 2020 at 09:09 GMT
# USD                               NaN
# GBP                               NaN
#
#                                                    disclaimer chartName  \
# updated     This data was produced from the CoinDesk Bitco...   Bitcoin
# updatedISO  This data was produced from the CoinDesk Bitco...   Bitcoin
# updateduk   This data was produced from the CoinDesk Bitco...   Bitcoin
# USD         This data was produced from the CoinDesk Bitco...   Bitcoin
# GBP         This data was produced from the CoinDesk Bitco...   Bitcoin
#
#                                                           bpi
# updated                                                   NaN
# updatedISO                                                NaN
# updateduk                                                 NaN
# ...

# %%
df_json
# Out:
#                                  time  \
# updated     Nov 23, 2020 09:04:00 UTC
# updatedISO  2020-11-23T09:04:00+00:00
# updateduk   Nov 23, 2020 at 09:04 GMT
# USD                               NaN
# GBP                               NaN
# EUR                               NaN
#
#                                                    disclaimer chartName  \
# updated     This data was produced from the CoinDesk Bitco...   Bitcoin
# updatedISO  This data was produced from the CoinDesk Bitco...   Bitcoin
# updateduk   This data was produced from the CoinDesk Bitco...   Bitcoin
# USD         This data was produced from the CoinDesk Bitco...   Bitcoin
# GBP         This data was produced from the CoinDesk Bitco...   Bitcoin
# EUR         This data was produced from the CoinDesk Bitco...   Bitcoin
#
#                                                           bpi
# updated                                                   NaN
# updatedISO                                                NaN
# ...

# %%
df_json.to_pickle('pickle.pickle')

# %%
newdf = pd.read_pickle('pickle.pickle')

# %%
newdf.head()
# Out:
#                                  time  \
# updated     Nov 23, 2020 09:09:00 UTC
# updatedISO  2020-11-23T09:09:00+00:00
# updateduk   Nov 23, 2020 at 09:09 GMT
# USD                               NaN
# GBP                               NaN
#
#                                                    disclaimer chartName  \
# updated     This data was produced from the CoinDesk Bitco...   Bitcoin
# updatedISO  This data was produced from the CoinDesk Bitco...   Bitcoin
# updateduk   This data was produced from the CoinDesk Bitco...   Bitcoin
# USD         This data was produced from the CoinDesk Bitco...   Bitcoin
# GBP         This data was produced from the CoinDesk Bitco...   Bitcoin
#
#                                                           bpi
# updated                                                   NaN
# updatedISO                                                NaN
# updateduk                                                 NaN
# ...

# %%
import pickle
pickle_out = open('newdf.pickle', 'wb')

# %%
pickle.dump(newdf, pickle_out)
pickle_out.close()

# %%
pickle_in = open('newdf.pickle', 'rb')
read_pickle = pickle.load(pickle_in)
print(read_pickle)
# Out:
#                                  time  \
# updated     Nov 23, 2020 09:09:00 UTC
# updatedISO  2020-11-23T09:09:00+00:00
# updateduk   Nov 23, 2020 at 09:09 GMT
# USD                               NaN
# GBP                               NaN
# EUR                               NaN
#
#                                                    disclaimer chartName  \
# updated     This data was produced from the CoinDesk Bitco...   Bitcoin
# updatedISO  This data was produced from the CoinDesk Bitco...   Bitcoin
# updateduk   This data was produced from the CoinDesk Bitco...   Bitcoin
# USD         This data was produced from the CoinDesk Bitco...   Bitcoin
# GBP         This data was produced from the CoinDesk Bitco...   Bitcoin
# EUR         This data was produced from the CoinDesk Bitco...   Bitcoin
#
#                                                           bpi
# updated                                                   NaN
# updatedISO                                                NaN
# ...

# %%
print(read_pickle.head())
# Out:
#                                  time  \
# updated     Nov 23, 2020 09:09:00 UTC
# updatedISO  2020-11-23T09:09:00+00:00
# updateduk   Nov 23, 2020 at 09:09 GMT
# USD                               NaN
# GBP                               NaN
#
#                                                    disclaimer chartName  \
# updated     This data was produced from the CoinDesk Bitco...   Bitcoin
# updatedISO  This data was produced from the CoinDesk Bitco...   Bitcoin
# updateduk   This data was produced from the CoinDesk Bitco...   Bitcoin
# USD         This data was produced from the CoinDesk Bitco...   Bitcoin
# GBP         This data was produced from the CoinDesk Bitco...   Bitcoin
#
#                                                           bpi
# updated                                                   NaN
# updatedISO                                                NaN
# updateduk                                                 NaN
# ...

# %%
import time
start = time.time()
df_json.to_pickle('pickle.pickle')
newdf = pd.read_pickle('pickle.pickle')
print(time.time()-start)

start = time.time()
pickle_out = open('pickle.pickle', 'wb')
pickle.dump(newdf, pickle_out)
pickle_out.close()
pickle_in = open('pickle.pickle', 'rb')
read_pickle = pickle.load(pickle_in)
print(time.time()-start)
# Out:
# 0.12363886833190918
# 0.007993459701538086
